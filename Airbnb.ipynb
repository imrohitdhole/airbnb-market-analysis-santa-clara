# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import necessary libraries
import pandas as pd

# Load data
listings = pd.read_csv('listings.csv')
reviews = pd.read_csv('reviews.csv')
neighbourhoods = pd.read_csv('neighbourhoods.csv')

# Preview data
listings.head()
# Out:
#       id                                               name  host_id  \
# 0   4952   Butterfly Inn near Stanford with weekly cleaning     7054
# 1  11464  Deluxe Studio near Kaiser SC:Traveler/Tesla in...    42458
# 2  21373   Bonsai Garden near Stanford with weekly cleaning     7054
# 3  62799  Zen Bedroom in Palo Alto, includes weekly clea...     7054
# 4  75284  Garden Oasis walk to Stanford with weekly clea...     7054
#
#   host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0   Mei Lin                  NaN     Palo Alto  37.43932 -122.15741
# 1      Emey                  NaN   Santa Clara  37.34415 -121.98701
# 2   Mei Lin                  NaN     Palo Alto  37.43972 -122.15532
# 3   Mei Lin                  NaN     Palo Alto  37.43934 -122.15723
# 4   Mei Lin                  NaN     Palo Alto  37.43923 -122.15745
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Cleaning the Listings Dataset
# Drop unnecessary columns and handle missing values

# Drop columns with minimal or no relevant data for analysis
listings_cleaned = listings.drop(columns=['neighbourhood_group', 'license'])

# Remove rows where 'price' is missing as it's essential
listings_cleaned = listings_cleaned.dropna(subset=['price'])

# Fill missing values in 'reviews_per_month' with 0 (assume no reviews if NaN)
listings_cleaned['reviews_per_month'].fillna(0, inplace=True)

# Convert 'last_review' to datetime
listings_cleaned['last_review'] = pd.to_datetime(listings_cleaned['last_review'], errors='coerce')

# Cleaning the Reviews Dataset
# Since there are no missing values in reviews, no further cleaning is needed for it

# Cleaning the Neighborhoods Dataset
# Drop the empty 'neighbourhood_group' column if it exists
neighbourhoods_cleaned = neighbourhoods.drop(columns=['neighbourhood_group'], errors='ignore')

# Saving the cleaned datasets to CSV files
listings_cleaned_path = "/content/drive/MyDrive/Airbnb/listings_cleaned.csv"
reviews_cleaned_path = "/content/drive/MyDrive/Airbnb/reviews_cleaned.csv"
neighbourhoods_cleaned_path = "/content/drive/MyDrive/Airbnb/neighbourhoods_cleaned.csv"

listings_cleaned.to_csv(listings_cleaned_path, index=False)
reviews.to_csv(reviews_cleaned_path, index=False)  # no cleaning needed for reviews
neighbourhoods_cleaned.to_csv(neighbourhoods_cleaned_path, index=False)

listings_cleaned_path.head, reviews_cleaned_path, neighbourhoods_cleaned_path
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-97330a0988ba> in <cell line: 5>()
#       3
#       4 # Drop columns with minimal or no relevant data for analysis
# ----> 5 listings_cleaned = listings.drop(columns=['neighbourhood_group', 'license'])
#       6
#       7 # Remove rows where 'price' is missing as it's essential
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# ...

# %%
# Import necessary libraries
import pandas as pd

# Load data
listings = pd.read_csv('listings.csv')
reviews = pd.read_csv('reviews.csv')
neighbourhoods = pd.read_csv('neighbourhoods.csv')

# Preview data
#listings.head()

# Cleaning the Listings Dataset
# Drop unnecessary columns and handle missing values

# Check for the correct column names in the DataFrame
print(listings.columns)  # Print the available columns

# Drop columns with minimal or no relevant data for analysis.
# If columns are not present, this will raise a KeyError, providing the missing column names.
# Use errors='ignore' to skip dropping columns if they are not present.
listings_cleaned = listings.drop(columns=['neighbourhood_group', 'license'], errors='ignore')

# Remove rows where 'price' is missing as it's essential
listings_cleaned = listings_cleaned.dropna(subset=['price'])

# Fill missing values in 'reviews_per_month' with 0 (assume no reviews if NaN)
listings_cleaned['reviews_per_month'].fillna(0, inplace=True)

# Convert 'last_review' to datetime
listings_cleaned['last_review'] = pd.to_datetime(listings_cleaned['last_review'], errors='coerce')

# Cleaning the Reviews Dataset
# Since there are no missing values in reviews, no further cleaning is needed for it

# Cleaning the Neighborhoods Dataset
# Drop the empty 'neighbourhood_group' column if it exists
neighbourhoods_cleaned = neighbourhoods.drop(columns=['neighbourhood_group'], errors='ignore')

# Saving the cleaned datasets to CSV files
listings_cleaned_path = "/content/drive/MyDrive/Airbnb/listings_cleaned.csv"
reviews_cleaned_path = "/content/drive/MyDrive/Airbnb/reviews_cleaned.csv"
neighbourhoods_cleaned_path = "/content/drive/MyDrive/Airbnb/neighbourhoods_cleaned.csv"

listings_cleaned.to_csv(listings_cleaned_path, index=False)
reviews.to_csv(reviews_cleaned_path, index=False)  # no cleaning needed for reviews
neighbourhoods_cleaned.to_csv(neighbourhoods_cleaned_path, index=False)

listings_cleaned.head(), reviews_cleaned_path, neighbourhoods_cleaned_path
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')
# (      id                                               name  host_id  \
#  0   4952   Butterfly Inn near Stanford with weekly cleaning     7054
#  1  11464  Deluxe Studio near Kaiser SC:Traveler/Tesla in...    42458
#  2  21373   Bonsai Garden near Stanford with weekly cleaning     7054
#  3  62799  Zen Bedroom in Palo Alto, includes weekly clea...     7054
#  4  75284  Garden Oasis walk to Stanford with weekly clea...     7054
#
#    host_name neighbourhood  latitude  longitude        room_type  price  \
#  0   Mei Lin     Palo Alto  37.43932 -122.15741     Private room   71.0
# ...

# %%
# Import necessary libraries
import pandas as pd

# Load data
listings = pd.read_csv('/content/drive/MyDrive/Airbnb/listings_cleaned.csv')
reviews = pd.read_csv('/content/drive/MyDrive/Airbnb/reviews_cleaned.csv')
neighbourhoods = pd.read_csv('/content/drive/MyDrive/Airbnb/neighbourhoods_cleaned.csv')

# %% [markdown]
# 1. Price Analysis Dashboard
#
# 1. Average Price by Neighborhood and Room Type

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Average price by neighborhood (Top 10)
top_neighborhoods_price = listings.groupby('neighbourhood')['price'].mean().nlargest(10)

plt.figure(figsize=(12, 6))

sns.barplot(x=top_neighborhoods_price.index, y=top_neighborhoods_price.values, hue=top_neighborhoods_price.index, palette="viridis", legend=False)
plt.title("Top 10 Neighborhoods by Average Price")
plt.xlabel("Neighborhood")
plt.ylabel("Average Price (USD)")
plt.xticks(rotation=45)
plt.show()

# %%
# Average price by room type
avg_price_room_type = listings.groupby('room_type')['price'].mean()

plt.figure(figsize=(8, 5))

sns.barplot(x=avg_price_room_type.index, y=avg_price_room_type.values, hue=avg_price_room_type.index, palette="viridis", legend=False)
plt.title("Average Price by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Average Price (USD)")
plt.show()

# %% [markdown]
# 2. Occupancy & Availability Dashboard

# %%
# Distribution of availability
plt.figure(figsize=(10, 6))
sns.histplot(listings['availability_365'], bins=30, kde=True, color="teal")
plt.title("Distribution of Availability (Days per Year)")
plt.xlabel("Days Available per Year")
plt.ylabel("Frequency")
plt.show()

# %%
# Occupancy by room type (assuming you have 'occupancy_by_room' calculated)
plt.figure(figsize=(8, 5))

sns.barplot(x=occupancy_by_room.index, y=occupancy_by_room.values, hue=occupancy_by_room.index, palette="cool", legend=False)
plt.title("Occupancy Rate by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Occupancy Rate")
plt.show()

# %% [markdown]
# 3. Review & Rating Insights Dashboard

# %%
# Top neighborhoods by number of reviews (assuming you have 'top_neighborhoods_reviews' calculated)
plt.figure(figsize=(12, 6))

sns.barplot(x=top_neighborhoods_reviews.index, y=top_neighborhoods_reviews.values, hue=top_neighborhoods_reviews.index, palette="magma", legend=False)
plt.title("Top Neighborhoods by Number of Reviews")
plt.xlabel("Neighborhood")
plt.ylabel("Number of Reviews")
plt.xticks(rotation=45)
plt.show()

# Top-reviewed listings
top_listings = listings.nlargest(10, 'number_of_reviews')[['name', 'neighbourhood', 'number_of_reviews']]
print(top_listings)
# Out:
#                                                    name         neighbourhood  \
# 801   Serene Casita in Backyard Garden (Stay at Flor...              San Jose
# 824           Cabana in Sierra Azul Open Space Preserve  Unincorporated Areas
# 621                 Private Guest-House in the Redwoods  Unincorporated Areas
# 474      Treehouse in Vineyard Overlooking Monterey Bay  Unincorporated Areas
# 200                             Charming Hidden Cottage             Los Gatos
# 1068                               Treehouse , San Jose  Unincorporated Areas
# 954   Hillside Retreat Private 2-Room Guest Unit & Pool              San Jose
# 781                     Silicon Valley Studio Apartment              San Jose
# 716                          SARATOGA EXECUTIVE COTTAGE              Saratoga
# 1396  Private Rm #3 in Renovated Silicon Valley Bung...  Unincorporated Areas
#
#       number_of_reviews
# 801                 908
# 824                 887
# 621                 808
# ...

# %% [markdown]
# 4. Host Analysis Dashboard

# %%
# Top hosts by number of listings (assuming you have 'top_hosts' calculated)
plt.figure(figsize=(12, 6))

sns.barplot(x=top_hosts.index.astype(str), y=top_hosts.values, hue=top_hosts.index.astype(str), palette="crest", legend=False)
plt.title("Top Hosts by Number of Listings")
plt.xlabel("Host ID")
plt.ylabel("Number of Listings")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 5. Geographic Distribution Dashboard

# %%
import folium

# Map showing all listings with their locations
m = folium.Map(location=[listings['latitude'].mean(), listings['longitude'].mean()], zoom_start=10)

# Add each listing as a point on the map
for idx, row in listings.iterrows():
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius=3,
                        color="blue",
                        fill=True,
                        fill_color="blue",
                        fill_opacity=0.6).add_to(m)

m
# Out:
# Output hidden; open in https://colab.research.google.com to view.
